# %%
# !pip install pandas
# !pip install shap
# !pip install xgboost scikit-learn pandas
# !pip install lime
# !pip install ipython==7.23.1

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\savan\Desktop\Magisterka\ED\projekt\data_iterative.csv")
data.head()
# Out:
#    id   age  sex  dataset  cp  trestbps   chol  fbs  restecg  thalch  exang  \
# 0   1  63.0    1        0   3     145.0  233.0    1        0   150.0      0
# 1   2  67.0    1        0   0     160.0  286.0    0        0   108.0      1
# 2   3  67.0    1        0   0     120.0  229.0    0        0   129.0      1
# 3   4  37.0    1        0   2     130.0  250.0    0        1   187.0      0
# 4   5  41.0    0        0   1     130.0  204.0    0        0   172.0      0
#
#    oldpeak  slope  ca  thal  num
# 0      2.3      0   0     0    0
# 1      1.5      1   3     1    2
# 2      2.6      1   2     2    1
# 3      3.5      0   0     1    0
# 4      1.4      2   0     1    0

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix
import seaborn as sns 
import matplotlib.pyplot as plt

y = data['num']
X = data.drop(columns=['num', 'id'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

random_forest_model = RandomForestClassifier(random_state=42)
random_forest_model.fit(X_train, y_train)
random_forest_model_probs = random_forest_model.predict_proba(X_test)

random_forest_model_auc_ovr = roc_auc_score(y_test, random_forest_model_probs, multi_class="ovr", average="macro")
print("ROC AUC (OvR):", random_forest_model_auc_ovr)

random_forest_model_y_pred = random_forest_model.predict(X_test)
print(f'Report:\n{classification_report(y_test, random_forest_model_y_pred)}')
sns.heatmap(confusion_matrix(y_test, random_forest_model_y_pred), annot=True, fmt="d")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Heatmap")
plt.show()
# Out:
# ROC AUC (OvR): 0.8337449682335791
# Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84        82
#            1       0.53      0.64      0.58        53
#            2       0.33      0.27      0.30        22
#            3       0.29      0.24      0.26        21
#            4       0.00      0.00      0.00         6
#
#     accuracy                           0.62       184
#    macro avg       0.40      0.40      0.40       184
# weighted avg       0.60      0.62      0.61       184

# %%
#------------------------------------------------- SHAP ------------------------------------------------
import shap
import math

shap.initjs()

explainer = shap.Explainer(random_forest_model)
shap_values = explainer.shap_values(X_test)

print("Variable Importance Plot - Global Interpretation")
figure = plt.figure()
shap.summary_plot(shap_values, X_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
explainer = shap.Explainer(random_forest_model.predict, X_test)
shap_values = explainer(X_train)
# Out:
# PermutationExplainer explainer: 737it [04:05,  2.95it/s]

# %%
sample_ind = 20
for i, feature in enumerate(X_test.columns):
    shap.partial_dependence_plot(
        feature,
        random_forest_model.predict,
        X_test,
        ice=False,
        model_expected_value=True,
        feature_expected_value=True,
        show=False,
        shap_values=shap_values[sample_ind: sample_ind + 1, :]
    )

# %%
# the waterfall_plot shows how we get from shap_values.base_values to model.predict(X)[sample_ind]
shap.plots.waterfall(shap_values[sample_ind], max_display=14)

# the beeswarm plot displays SHAP values for each feature across all examples,
# with colors indicating how the SHAP values correlate with feature values
shap.plots.beeswarm(shap_values)

shap.plots.heatmap(shap_values[:1000])
# Out:
# <Axes: xlabel='Instances'>

# %%
#------------------------------------------------- LIME ------------------------------------------------
from lime.lime_tabular import LimeTabularExplainer

feature_names = list(X_train.columns)
class_names = ['0', '1', '2', '3', '4']

explainer_lime = LimeTabularExplainer(
    X_train.values,
    feature_names=feature_names,
    class_names=class_names,
    mode='classification'
)

def predict_fn(x):
    x_df = pd.DataFrame(x, columns=feature_names)
    return random_forest_model.predict_proba(x_df)

exp_lime = explainer_lime.explain_instance(
    X_test.iloc[sample_ind].values,
    predict_fn,
    top_labels = 3
)

for label in exp_lime.top_labels:
    exp_lime.as_pyplot_figure(label=label)
    plt.show()

print("\n\n")
exp_lime.show_in_notebook()
print("\n\n")
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# ...

# %%
#------------------------------------------------- PFI ------------------------------------------------
from sklearn.inspection import permutation_importance

pfi = permutation_importance(random_forest_model, X_test, y_test, n_repeats = 30, random_state = 42, n_jobs=2)

for i in pfi.importances_mean.argsort()[::-1]:
    if pfi.importances_mean[i] - 2 * pfi.importances_std[i] > 0:
        print(f"{X_test.columns[i]:<8}"
              f"{pfi.importances_mean[i]:.3f}"
              f" +/- {pfi.importances_std[i]:.3f}")

sorted_importances_idx = pfi.importances_mean.argsort()
importances = pd.DataFrame(
    pfi.importances[sorted_importances_idx].T,
    columns=X.columns[sorted_importances_idx],
)

ax = importances.plot.box(vert=False, whis=10)
ax.set_title("Permutation Importances (test set)")
ax.axvline(x=0, color="k", linestyle="--")
ax.set_xlabel("Decrease in accuracy score")
ax.figure.tight_layout()
# Out:
# oldpeak 0.065 +/- 0.019
# cp      0.060 +/- 0.017
# dataset 0.056 +/- 0.018
# chol    0.040 +/- 0.015
# age     0.032 +/- 0.014
# thalch  0.029 +/- 0.015
# fbs     0.020 +/- 0.009
# thal    0.019 +/- 0.009
# ca      0.016 +/- 0.007
